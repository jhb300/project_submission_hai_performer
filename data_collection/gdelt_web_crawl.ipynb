# %% [markdown]
# # Web Crawling of GDELT data from 2013 - 2015
# GDELT makes all data from 2015 - present accessible via Google Big Query. For the data from 1979-2013 there is a masterfile available, that compresses the event data in that timeframe. For the time from 2013-2015 however, the data for the single days has to be downloaded seperately from their website. This is what this notebook is doing.

# %%
import os
import re
import requests
import zipfile

# %% [markdown]
# The links are extracted from the GDELT Website.

# %%
path_2014 = "./web_crawl_links/2014.txt"
path_2015 = "./web_crawl_links/2015.txt"

#reading contents of the text files, containing the links
with open(path_2014, 'r') as file:
    data_2014 = file.read()

with open(path_2015, 'r') as file:
    data_2015 = file.read()

#filtering out the links
pattern = r'([^\s]+\.zip)'
endings_2014 = re.findall(pattern, data_2014)
endings_2015 = re.findall(pattern, data_2015)

#building urls from links in text files
base_url = "http://data.gdeltproject.org/events/"
urls_2014 = [base_url + ending for ending in endings_2014]
urls_2015 = [base_url + ending for ending in endings_2015]


print(urls_2014)
print(urls_2015)
# Out:
# ['http://data.gdeltproject.org/events/20141231.export.CSV.zip', 'http://data.gdeltproject.org/events/20141230.export.CSV.zip', 'http://data.gdeltproject.org/events/20141229.export.CSV.zip', 'http://data.gdeltproject.org/events/20141228.export.CSV.zip', 'http://data.gdeltproject.org/events/20141227.export.CSV.zip', 'http://data.gdeltproject.org/events/20141226.export.CSV.zip', 'http://data.gdeltproject.org/events/20141225.export.CSV.zip', 'http://data.gdeltproject.org/events/20141224.export.CSV.zip', 'http://data.gdeltproject.org/events/20141223.export.CSV.zip', 'http://data.gdeltproject.org/events/20141222.export.CSV.zip', 'http://data.gdeltproject.org/events/20141221.export.CSV.zip', 'http://data.gdeltproject.org/events/20141220.export.CSV.zip', 'http://data.gdeltproject.org/events/20141219.export.CSV.zip', 'http://data.gdeltproject.org/events/20141218.export.CSV.zip', 'http://data.gdeltproject.org/events/20141217.export.CSV.zip', 'http://data.gdeltproject.org/events/20141216.export.CSV.zip', 'http://data.gdeltproject.org/events/20141215.export.CSV.zip', 'http://data.gdeltproject.org/events/20141214.export.CSV.zip', 'http://data.gdeltproject.org/events/20141213.export.CSV.zip', 'http://data.gdeltproject.org/events/20141212.export.CSV.zip', 'http://data.gdeltproject.org/events/20141211.export.CSV.zip', 'http://data.gdeltproject.org/events/20141210.export.CSV.zip', 'http://data.gdeltproject.org/events/20141209.export.CSV.zip', 'http://data.gdeltproject.org/events/20141208.export.CSV.zip', 'http://data.gdeltproject.org/events/20141207.export.CSV.zip', 'http://data.gdeltproject.org/events/20141206.export.CSV.zip', 'http://data.gdeltproject.org/events/20141205.export.CSV.zip', 'http://data.gdeltproject.org/events/20141204.export.CSV.zip', 'http://data.gdeltproject.org/events/20141203.export.CSV.zip', 'http://data.gdeltproject.org/events/20141202.export.CSV.zip', 'http://data.gdeltproject.org/events/20141201.export.CSV.zip', 'http://data.gdeltproject.org/events/20141130.export.CSV.zip', 'http://data.gdeltproject.org/events/20141129.export.CSV.zip', 'http://data.gdeltproject.org/events/20141128.export.CSV.zip', 'http://data.gdeltproject.org/events/20141127.export.CSV.zip', 'http://data.gdeltproject.org/events/20141126.export.CSV.zip', 'http://data.gdeltproject.org/events/20141125.export.CSV.zip', 'http://data.gdeltproject.org/events/20141124.export.CSV.zip', 'http://data.gdeltproject.org/events/20141123.export.CSV.zip', 'http://data.gdeltproject.org/events/20141122.export.CSV.zip', 'http://data.gdeltproject.org/events/20141121.export.CSV.zip', 'http://data.gdeltproject.org/events/20141120.export.CSV.zip', 'http://data.gdeltproject.org/events/20141119.export.CSV.zip', 'http://data.gdeltproject.org/events/20141118.export.CSV.zip', 'http://data.gdeltproject.org/events/20141117.export.CSV.zip', 'http://data.gdeltproject.org/events/20141116.export.CSV.zip', 'http://data.gdeltproject.org/events/20141115.export.CSV.zip', 'http://data.gdeltproject.org/events/20141114.export.CSV.zip', 'http://data.gdeltproject.org/events/20141113.export.CSV.zip', 'http://data.gdeltproject.org/events/20141112.export.CSV.zip', 'http://data.gdeltproject.org/events/20141111.export.CSV.zip', 'http://data.gdeltproject.org/events/20141110.export.CSV.zip', 'http://data.gdeltproject.org/events/20141109.export.CSV.zip', 'http://data.gdeltproject.org/events/20141108.export.CSV.zip', 'http://data.gdeltproject.org/events/20141107.export.CSV.zip', 'http://data.gdeltproject.org/events/20141106.export.CSV.zip', 'http://data.gdeltproject.org/events/20141105.export.CSV.zip', 'http://data.gdeltproject.org/events/20141104.export.CSV.zip', 'http://data.gdeltproject.org/events/20141103.export.CSV.zip', 'http://data.gdeltproject.org/events/20141102.export.CSV.zip', 'http://data.gdeltproject.org/events/20141101.export.CSV.zip', 'http://data.gdeltproject.org/events/20141031.export.CSV.zip', 'http://data.gdeltproject.org/events/20141030.export.CSV.zip', 'http://data.gdeltproject.org/ ...
# ['http://data.gdeltproject.org/events/20151231.export.CSV.zip', 'http://data.gdeltproject.org/events/20151230.export.CSV.zip', 'http://data.gdeltproject.org/events/20151229.export.CSV.zip', 'http://data.gdeltproject.org/events/20151228.export.CSV.zip', 'http://data.gdeltproject.org/events/20151227.export.CSV.zip', 'http://data.gdeltproject.org/events/20151226.export.CSV.zip', 'http://data.gdeltproject.org/events/20151225.export.CSV.zip', 'http://data.gdeltproject.org/events/20151224.export.CSV.zip', 'http://data.gdeltproject.org/events/20151223.export.CSV.zip', 'http://data.gdeltproject.org/events/20151222.export.CSV.zip', 'http://data.gdeltproject.org/events/20151221.export.CSV.zip', 'http://data.gdeltproject.org/events/20151220.export.CSV.zip', 'http://data.gdeltproject.org/events/20151219.export.CSV.zip', 'http://data.gdeltproject.org/events/20151218.export.CSV.zip', 'http://data.gdeltproject.org/events/20151217.export.CSV.zip', 'http://data.gdeltproject.org/events/20151216.export.CSV.zip', 'http://data.gdeltproject.org/events/20151215.export.CSV.zip', 'http://data.gdeltproject.org/events/20151214.export.CSV.zip', 'http://data.gdeltproject.org/events/20151213.export.CSV.zip', 'http://data.gdeltproject.org/events/20151212.export.CSV.zip', 'http://data.gdeltproject.org/events/20151211.export.CSV.zip', 'http://data.gdeltproject.org/events/20151210.export.CSV.zip', 'http://data.gdeltproject.org/events/20151209.export.CSV.zip', 'http://data.gdeltproject.org/events/20151208.export.CSV.zip', 'http://data.gdeltproject.org/events/20151207.export.CSV.zip', 'http://data.gdeltproject.org/events/20151206.export.CSV.zip', 'http://data.gdeltproject.org/events/20151205.export.CSV.zip', 'http://data.gdeltproject.org/events/20151204.export.CSV.zip', 'http://data.gdeltproject.org/events/20151203.export.CSV.zip', 'http://data.gdeltproject.org/events/20151202.export.CSV.zip', 'http://data.gdeltproject.org/events/20151201.export.CSV.zip', 'http://data.gdeltproject.org/events/20151130.export.CSV.zip', 'http://data.gdeltproject.org/events/20151129.export.CSV.zip', 'http://data.gdeltproject.org/events/20151128.export.CSV.zip', 'http://data.gdeltproject.org/events/20151127.export.CSV.zip', 'http://data.gdeltproject.org/events/20151126.export.CSV.zip', 'http://data.gdeltproject.org/events/20151125.export.CSV.zip', 'http://data.gdeltproject.org/events/20151124.export.CSV.zip', 'http://data.gdeltproject.org/events/20151123.export.CSV.zip', 'http://data.gdeltproject.org/events/20151122.export.CSV.zip', 'http://data.gdeltproject.org/events/20151121.export.CSV.zip', 'http://data.gdeltproject.org/events/20151120.export.CSV.zip', 'http://data.gdeltproject.org/events/20151119.export.CSV.zip', 'http://data.gdeltproject.org/events/20151118.export.CSV.zip', 'http://data.gdeltproject.org/events/20151117.export.CSV.zip', 'http://data.gdeltproject.org/events/20151116.export.CSV.zip', 'http://data.gdeltproject.org/events/20151115.export.CSV.zip', 'http://data.gdeltproject.org/events/20151114.export.CSV.zip', 'http://data.gdeltproject.org/events/20151113.export.CSV.zip', 'http://data.gdeltproject.org/events/20151112.export.CSV.zip', 'http://data.gdeltproject.org/events/20151111.export.CSV.zip', 'http://data.gdeltproject.org/events/20151110.export.CSV.zip', 'http://data.gdeltproject.org/events/20151109.export.CSV.zip', 'http://data.gdeltproject.org/events/20151108.export.CSV.zip', 'http://data.gdeltproject.org/events/20151107.export.CSV.zip', 'http://data.gdeltproject.org/events/20151106.export.CSV.zip', 'http://data.gdeltproject.org/events/20151105.export.CSV.zip', 'http://data.gdeltproject.org/events/20151104.export.CSV.zip', 'http://data.gdeltproject.org/events/20151103.export.CSV.zip', 'http://data.gdeltproject.org/events/20151102.export.CSV.zip', 'http://data.gdeltproject.org/events/20151101.export.CSV.zip', 'http://data.gdeltproject.org/events/20151031.export.CSV.zip', 'http://data.gdeltproject.org/events/20151030.export.CSV.zip', 'http://data.gdeltproject.org/ ...

# %% [markdown]
# Now the extracted links are used to scrape the data from the GDELT servers and save it in the downloaded_files folder. WARNING: This may take up to 30 minutes, depending on your internet connection.

# %%
years = [urls_2014, urls_2015]

for year in years:
    for url in year:
        # Get the current working directory
        current_dir = os.getcwd()

        # Create a folder to save downloaded files if it doesn't exist
        folder_name = 'downloaded_files'
        folder_path = os.path.join(current_dir, folder_name)
        os.makedirs(folder_path, exist_ok=True)

        # Determine the file name from the URL
        file_name = url.split('/')[-1]

        # Specify the file path where the downloaded zip folder should be saved
        zip_file_path = os.path.join(folder_path, file_name)

        # Download the zip folder and save it to the specified location
        response = requests.get(url)
        with open(zip_file_path, 'wb') as file:
            file.write(response.content)

        # Extract the contents of the zip folder
        extract_folder_path = os.path.join(folder_path, file_name.split('.')[0])
        with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
            zip_ref.extractall(extract_folder_path)

        # Get the file inside the extracted folder
        files_in_extracted_folder = os.listdir(extract_folder_path)
        if len(files_in_extracted_folder) > 0:
            file_to_save = os.path.join(extract_folder_path, files_in_extracted_folder[0])

            # Specify the file path where the extracted file should be saved
            saved_file_path = os.path.join(folder_path, files_in_extracted_folder[0])
            
            # Move the file to the desired location
            os.rename(file_to_save, saved_file_path)
            print(f"File downloaded and saved to: {saved_file_path}")
        else:
            print("No files found inside the extracted folder.")

        # Clean up the extracted folder
        os.rmdir(extract_folder_path)
        print(f"Zip folder downloaded and extracted to: {extract_folder_path}")

        # Delete the downloaded zip folder
        os.remove(zip_file_path)
        print(f"Zip folder deleted: {zip_file_path}")
# Out:
# File downloaded and saved to: /Users/adavidho/Documents/University/DHBW/Semester 4/Data Exploration/Project/project_submission_haiperformer/data_collection/downloaded_files/20141231.export.CSV
# Zip folder downloaded and extracted to: /Users/adavidho/Documents/University/DHBW/Semester 4/Data Exploration/Project/project_submission_haiperformer/data_collection/downloaded_files/20141231
# Zip folder deleted: /Users/adavidho/Documents/University/DHBW/Semester 4/Data Exploration/Project/project_submission_haiperformer/data_collection/downloaded_files/20141231.export.CSV.zip
# File downloaded and saved to: /Users/adavidho/Documents/University/DHBW/Semester 4/Data Exploration/Project/project_submission_haiperformer/data_collection/downloaded_files/20141230.export.CSV
# Zip folder downloaded and extracted to: /Users/adavidho/Documents/University/DHBW/Semester 4/Data Exploration/Project/project_submission_haiperformer/data_collection/downloaded_files/20141230
# Zip folder deleted: /Users/adavidho/Documents/University/DHBW/Semester 4/Data Exploration/Project/project_submission_haiperformer/data_collection/downloaded_files/20141230.export.CSV.zip
# File downloaded and saved to: /Users/adavidho/Documents/University/DHBW/Semester 4/Data Exploration/Project/project_submission_haiperformer/data_collection/downloaded_files/20141229.export.CSV
# Zip folder downloaded and extracted to: /Users/adavidho/Documents/University/DHBW/Semester 4/Data Exploration/Project/project_submission_haiperformer/data_collection/downloaded_files/20141229
# Zip folder deleted: /Users/adavidho/Documents/University/DHBW/Semester 4/Data Exploration/Project/project_submission_haiperformer/data_collection/downloaded_files/20141229.export.CSV.zip
# File downloaded and saved to: /Users/adavidho/Documents/University/DHBW/Semester 4/Data Exploration/Project/project_submission_haiperformer/data_collection/downloaded_files/20141228.export.CSV
# Zip folder downloaded and extracted to: /Users/adavidho/Documents/University/DHBW/Semester 4/Data Exploration/Project/project_submission_haiperformer/data_collection/downloaded_files/20141228
# Zip folder deleted: /Users/adavidho/Documents/University/DHBW/Semester 4/Data Exploration/Project/project_submission_haiperformer/data_collection/downloaded_files/20141228.export.CSV.zip
# File downloaded and saved to: /Users/adavidho/Documents/University/DHBW/Semester 4/Data Exploration/Project/project_submission_haiperformer/data_collection/downloaded_files/20141227.export.CSV
# Zip folder downloaded and extracted to: /Users/adavidho/Documents/University/DHBW/Semester 4/Data Exploration/Project/project_submission_haiperformer/data_collection/downloaded_files/20141227
# Zip folder deleted: /Users/adavidho/Documents/University/DHBW/Semester 4/Data Exploration/Project/project_submission_haiperformer/data_collection/downloaded_files/20141227.export.CSV.zip
# File downloaded and saved to: /Users/adavidho/Documents/University/DHBW/Semester 4/Data Exploration/Project/project_submission_haiperformer/data_collection/downloaded_files/20141226.export.CSV
# Zip folder downloaded and extracted to: /Users/adavidho/Documents/University/DHBW/Semester 4/Data Exploration/Project/project_submission_haiperformer/data_collection/downloaded_files/20141226
# Zip folder deleted: /Users/adavidho/Documents/University/DHBW/Semester 4/Data Exploration/Project/project_submission_haiperformer/data_collection/downloaded_files/20141226.export.CSV.zip
# File downloaded and saved to: /Users/adavidho/Documents/University/DHBW/Semester 4/Data Exploration/Project/project_submission_haiperformer/data_collection/downloaded_files/20141225.export.CSV
# Zip folder downloaded and extracted to: /Users/adavidho/Documents/University/DHBW/Semester 4/Data Exploration/Project/project_submission_haiperformer/data_collection/downloaded_files/20141225
# Zip folder deleted: /Users/adavidho/Documents/University/DHBW/Semester 4/Data Exploration/Project/project_submission_haiperformer/data_collection/downloaded_files/20141225.export.CSV.zip
# File downloaded and saved to: /Users/adavidho/Documents/University/DHBW/Semester 4/Data Exploration/Project/project_submission_haiperformer/data_collection/downloaded_files/20141224.export.CSV
# Zip folder downloaded and extracted to: /Users/adavidho/Documents/University/DHBW/Semester 4/Data Exploration/Project/project_submission_haiperformer/data_collection/downloaded_files/20141224
# Zip folder deleted: /Users/adavidho/Documents/University/DHBW/Semester 4/Data Exploration/Project/project_submission_haiperformer/data_collection/downloaded_files/20141224.export.CSV.zip
# File downloaded and saved to: /Users/adavidho/Documents/University/DHBW/Semester 4/Data Exploration/Project/project_submission_haiperformer/data_collection/downloaded_files/20141223.export.CSV
# Zip folder downloaded and extracted to: /Users/adavidho/Documents/University/DHBW/Semester 4/Data Exploration/Project/project_submission_haiperformer/data_collection/downloaded_files/20141223
# Zip folder deleted: /Users/adavidho/Documents/University/DHBW/Semester 4/Data Exploration/Project/project_submission_haiperformer/data_collection/downloaded_files/20141223.export.CSV.zip
